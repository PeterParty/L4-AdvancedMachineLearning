# %% [markdown]
# # Practice Project - Model Optimization Challenge
# ## Image Classification

# %% [markdown]
# ### Topics
# * (Cross-validation)[]
#
# ### Requirements
# * Build baseline model
# * Apply cross-validation
# * Tune at last 5 hyperparameters
# * Compare results of different hypertuning methods( random search, grid search, bayesian optimization )  configurations
# * Plot loss function curves
#
# ### Deliverables
# * Perfomrance improvement log
# * Final tuned model
# * Explanation:
#     * Bias vs variance
#     * Why selected final model?
